# %% [markdown]
# ## Questão 1
#
# ### Definições:
#
# - **Objetivo:** Prever os autores de obras de arte do impressionismo.
# - **Ambiente:** Museu de arte, quadros e desenhos.
# - **Atuadores/ações:** Software que informa autor da obra de acordo com as características da imagem.
# - **Sensores/percepções:** Pixels de intensidade variável e cor.
# - **Medidas de desempenho:** Número de acertos.
#
# ### De onde virão os dados ?
#
# Eu iria sugerir a construção de uma base de dados seguindo um passo a passo semelhante ao descrito na criação da base [Impressionist_Classifier_Data](https://www.kaggle.com/datasets/delayedkarma/impressionist-classifier-data), no qual primeiro todo conteúdo relevante é baixado do [Wikiart](https://www.wikiart.org/en/paintings-by-style/impressionism#!#filterName:all-works,viewType:masonry), que no caso da criação da base para identificar autores impressionistas o ideal seria baixar todas as imagens impressionistas que possuem o nome do autor, e para isso seria usado um script (implementado pessoalmente ou utilizando o repositório público: [lucasdavid/wikiart](https://github.com/lucasdavid/wikiart)) que baixa as imagens e as organiza em diretórios diferentes de acodo o nome do autor.
#
# ### Como será a entrada ?
#
# A entrada no geral é uma imagem, pode ser uma foto tirada de um quadro ou um desenho, ou até mesmo um desenho feito digitalmente e exportado no formato de imagem padrão.
#
# ### Exemplos de entrada e saída:
#
# 1. **Entrada:** Foto do quadro "Road to the Saint-Simeon Farm". **Saída:** Claúdio Monet.
# 2. **Entrada:** Desenho feito digitalmente do quadro "Tableau I". **Saída:** Piet Mondrian.
# 3. **Entrada:** Foto de um desenho do quadro "Young Spartans Exercising". **Saída:** Edgar Degas.
# 4. **Entrada:** Desenho feito digitalmente do quadro "Farm in Normandy". **Saída:** Autor não reconhecido.
# 5. **Entrada:** Foto do quadro "Music in the Tuileries Garden". **Saída:** Edouard Manet.

# %% [markdown]
# ## Questão 2
#
# ### Classificação
#
# - **Base:** [English Premier League(2020-21)](https://www.kaggle.com/datasets/rajatrc1705/english-premier-league202021).
#
# - **Entradas:** Idade, número de jogos, tempo jogado, assitências e gols.
# - **Saída:** Posição que atende melhor as características do jogador.
# - **Motivação da previsão da saída:** Ajudar o time a entender qual a melhor posicação para os seus jogadores da base e do time principal de acordo com suas caracteríscas.
#
# ### Regressão
#
# - **Base:** [World University Rankings 2021](https://www.kaggle.com/datasets/matheusgratz/world-university-rankings-2021).
#
# - **Entradas:** Pontuação dos professores, potuação de pesquisa e potuação de citações.
# - **Saída:** Previsão da pontuação de renda do setor.
# - **Motivação da previsão da saída:** Analisar quais pontos da universidade devem ser fortificados para se ter uma maior potuação de renda do setor.
#
# ### Classificação ou Regressão
#
# - **Base:** [LoL Challenger Soloq Data (Jan, Kr-Na-Euw)](https://www.kaggle.com/datasets/andrewasuter/lol-challenger-soloq-data-jan-krnaeuw).
#
# #### Classificação
#
# - **Entradas:** Número de assistências, dano em torres, dano em objetivos e dano total.
# - **Saída:** Rotular campeões que melhor atendem as características de entrada.
# - **Motivação da previsão da saída:** Ajudar times em competições profissionais, pois os pontos fortes e fracos dos times são conhecidos e medidos a partir das características de entrada, como: um time é bom em derrubar torres, então tem o seu dano em torres é alto, mas esse time não tem um número de abates bom, então seu dano total é baixo. Nesse sentido, saber quais campeões atendem melhor as características dos times pode fazer um time ter vantagem sobre seu adversário.
#
# #### Regressão
#
# - **Entradas:** Campeões, função no jogo (role) e lado do mapa.
# - **Saída:** Previsão de dano em torres.
# - **Motivação da previsão da saída:** Também ajudar times em competições profissionais, mas em um estágio diferente, que seria depois de os times já terem escolhido seus campeões, a função de cada jogador e o lado do mapa, pois a partir da saída os jogadores teriam a informação de quanto da estratégia de derrubar torres pode ser explorada ao longo da partida, isso pode ser importante para definir o objetivo principal do time na partida.

# %% [markdown]
# ## Questão 3
#
# ### Supervisionado
#
# - **Base:** [Anime DataSet 2022](https://www.kaggle.com/datasets/vishalmane10/anime-dataset-2022).
#
# - O exemplo abaixo utiliza a base de dados [Anime DataSet 2022](https://www.kaggle.com/datasets/vishalmane10/anime-dataset-2022) para resolver um problema de regressão do aprendizado supervisionado.
#
# ##### Regressão
#
# - **Entradas:** Tipo (forma de distribuição), número de episódios, estúdio de produção, temporada de lançamento, gêneros (tags).
# - **Saída:** Previsão da avaliação dos usuários.
# - **Motivação da previsão da saída:** Analisar qual o grau de aceitação da comunidade as características de um novo anime.
#
# ### Não supervisionado
#
# - **Base:** [Customer Personality Analysis](https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis).
#
# - **Entradas:** Data de nascimento, nível de educação, renda e número de filhos.
# - **Saída:** Conjuntos agrupados nas categorias - solteiro(a), noivo(a), casado(a) e divorciado(a).
# - **Motivação da previsão da saída:** Em uma rede social é importante conhecer as pessoas com características semelhantes para recomendar produtos e conteúdos da aplicação de acordo com essas características. Nesse contexto, a saída pode ser usada para identificar usuários solteiros e recomendar a conexão entre eles.
#
# ### Supervisionado e não supervisionado
#
# - **Base:** [State of Data Brazil 2021](https://www.kaggle.com/datasets/datahackers/state-of-data-2021).
#
# ##### Supervisionado
#
# - O exemplo abaixo utiliza a base de dados [State of Data Brazil 2021](https://www.kaggle.com/datasets/datahackers/state-of-data-2021) para resolver um problema de classificação do aprendizado supervisionado.
#
#
# - **Entradas:** Idade, UF de onde mora, região onde mora, região de origem, mudou de estado ou não e gênero da pessoa.
# - **Saída:** Rotular nível de ensino que atende melhor as características de entrada.
# - **Motivação da previsão da saída:** Pode ser interessante para recrutadores de empresas procurando por possíveis candidatos na internet, pois quando este dado está faltando o sistema poderia sugerir qual é o nível de ensino com maior probabilidade do possível candidato ter, a partir disso, o recrutador vai ter uma melhor noção do candidato e saber se vale apena fazer a abordagem ou não.
#
# ##### Não supervisionado
#
# - **Entradas:** Idade, UF de onde mora, região onde mora, região de origem, mudou de estado ou não, gênero da pessoa e nível de ensino.
# - **Saída:** Conjuntos agrupados pelo estado de origem.
# - **Motivação da previsão da saída:** Pode ser interassente para empresas, no sentido de analise dos funcionários e distribuição desses nos projetos da empresa.

# %% [markdown]
# ### Próximos passos
#
# 1. Terminar questões 1, 2 e 3 de maneira semi definitiva.
#     1.1 Revisar conteúdo para me certificar de fato que as respostas estão no sentido correto.
#     1.2 Melhor explicação das respostas.
#     1.3 Organizar respostas.
# 2. Fazer próximas questões seguindo essa ordem. (4, 5, 6 e 7)
#
# #### Metas:
#
# 1. Terminar questões 1, 2 e 3 no máximo até domingo.
# 2. Começar implementação da 4 para ter uma noção de oque devo focar ao longo da semana.

# %% [markdown]
# ## Questão 4
#
# - **Base escolhida:** [English Premier League(2020-21)](https://www.kaggle.com/datasets/rajatrc1705/english-premier-league202021).

# %%
import pandas as pd
import numpy as np
import statistics as st
import matplotlib.pyplot as plt
import plotly.express as px
import math
from sklearn import preprocessing
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split


import seaborn as sns
sns.set()

# %%
import pandas as pd
df = pd.read_csv('./EPL_20_21.csv')
df
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    MF,FW   21       36
# 1        Edouard Mendy           Chelsea         SEN       GK   28       31
# 2          Timo Werner           Chelsea         GER       FW   24       35
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    DF,FW   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
#      Starts  Mins  Goals  Assists  Passes_Attempted  Perc_Passes_Completed  \
# 0        32  2890      6        5              1881                   82.3
# 1        31  2745      0        0              1007                   84.6
# 2        29  2602      6        8               826                   77.2
# 3        27  2286      3        5              1806                   78.6
# 4        25  2373      1        2              1987                   85.0
# ..      ...   ...    ...      ...               ...                    ...
# 527       2   296      0        0                50                   80.0
# 528       2   180      0        0                77                   77.9
# 529       0    12      0        0                 3                  100.0
# 530       0    11      0        0                 1                  100.0
# 531       0     1      0        0                 0                   -1.0
#
#      Penalty_Goals  Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# 0                1                  1  0.21  0.24             2          0
# 1                0                  0  0.00  0.00             2          0
# 2                0                  0  0.41  0.21             2          0
# 3                0                  0  0.10  0.11             3          0
# 4                0                  0  0.06  0.12             3          0
# ..             ...                ...   ...   ...           ...        ...
# 527              0                  0  0.22  0.10             0          0
# 528              0                  0  0.00  0.00             0          0
# 529              0                  0  0.00  0.00             0          0
# 530              0                  0  1.16  0.00             0          0
# 531              0                  0  0.00  0.00             0          0
#
# [532 rows x 18 columns]

# %% [markdown]
# ### 1 - Aplique processos de pré-processamento necessários para execução do método K-NN

# %%
#verificar se há dados faltosos
print('Valores faltantes:\n', df.isnull().sum())

# %%
#verificar tipos presentes nos dados
df.info(verbose=True)

# %%
#transformar valores de 'Position' para considerar apenas a posição mais jogada

#df['Position'].str.split(',', expand = True)
df['Position'] = df['Position'].str.split(',').str.get(0)
df

# %%
#transformar atributos qualitativos em quantitativos

le = preprocessing.LabelEncoder()
for column in df.columns:
    if df[column].dtypes == 'object':
          df[column] = le.fit_transform(df[column])
print(df)

# %%
#verificar cada classe de forma geral
df.describe()

# %%
#verificar classe alvo de forma geral
print(df['Position'].describe())

#plotar gráfico boxplot para facilitar visualização dos dados
plt.boxplot(df['Position'])
plt.title('title')
plt.xlabel('valores')
plt.ylabel('campeão')

#identificação dos rótulos:
# 0 - DF
# 1 - FW
# 2 - GK
# 3 - MF

#análise dos dados obtidos:

# os dados são assimétricos positivos (a maior parte dos dados estão abaixo da mediana)
# não possui outliers
# os valores mínimo e máximo estão presentes nos quartis 1 e 3
# possui dispersão alta dispersão

# %%
#verificar se há valores duplicados
print('Valores duplicados:\n', df.duplicated())

# %%
#verificar porcentagem de cada classe de saída
x = df['Position'].value_counts()/len(df)
x

#identificação das classes:
# 0 - DF
# 1 - FW
# 2 - GK
# 3 - MF

#A classe GK é menos presente nos dados, isso pode ser explicado, pois existe apenas um jogador que ocupa a
#posição de goleiro por time.

# %%
#verificando correlação dos dados
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')

#Starts e Mins possuem um alta correlação
#Mins e Matches possuem uma alta correção
#Starts e Matches possuem uma alta correlação
#Passes_Attempted e Starts possuem uma alta correlação
#Passes_Attempted e Mins possuem uma alta correlação

# %%
#remover Starts e Mins, para que fique apenas valores representativos na base
dfcorr = df.drop(columns=['Starts', 'Mins'])

#analisando nova correlação
corr2 = dfcorr.corr()
corr2.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_532af_row0_col0, #T_532af_row1_col1, #T_532af_row2_col2, #T_532af_row3_col3, #T_532af_row4_col4, #T_532af_row5_col5, #T_532af_row6_col6, #T_532af_row7_col7, #T_532af_row8_col8, #T_532af_row9_col9, #T_532af_row10_col10, #T_532af_row11_col11, #T_532af_row12_col12, #T_532af_row13_col13, #T_532af_row14_col14, #T_532af_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_532af_row0_col1, #T_532af_row0_col4, #T_532af_row0_col7, #T_532af_row2_col0, #T_532af_row14_col2, #T_532af_row15_col9 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_532af_row0_col2, #T_532af_row5_col9, #T_532af_row11_col15, #T_532af_row15_col4 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_532af_row0_col3, #T_532af_row2_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_532af_row0_col5, #T_532af_row10_col0, #T_532af_row11_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_532af_row0_col6, #T_532af_row1_col4, #T_532af_row2_col9, #T_532af_row3_col0, #T_532af_row4_col2, #T_532af_row4_col3, #T_532af_row10_col2, #T_532af_row11_col2, #T_532af_row12_col15, #T_532af_row15_col2, #T_532af_row15_col12 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_532af_row0_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_532af_row0_col9, #T_532af_row3_col5, #T_532af_row3_col12, #T_532af_row9_col0, #T_532af_row9_col15, #T_532af_row10_col4, #T_532af_row12_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_532af_row0_col10, #T_532af_row0_col11, #T_532af_row1_col11, #T_532af_row2_col5, #T_532af_row2_col6, #T_532af_row2_col7, #T_532af_row3_col15, #T_532af_row5_col0, #T_532af_row7_col2, #T_532af_row8_col12, #T_532af_row9_col10, #T_532af_row12_col0, #T_532af_row12_col4, #T_532af_row12_col8, #T_532af_row12_col9, #T_532af_row12_col14, #T_532af_row14_col12, #T_532af_row15_col1, #T_532af_row15_col3, #T_532af_row15_col13 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_532af_row0_col12, #T_532af_row2_col4, #T_532af_row3_col8, #T_532af_row6_col1, #T_532af_row7_col1, #T_532af_row8_col3, #T_532af_row9_col12, #T_532af_row13_col2, #T_532af_row15_col11 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_532af_row0_col13, #T_532af_row6_col0, #T_532af_row7_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_532af_row0_col14, #T_532af_row7_col4, #T_532af_row13_col9, #T_532af_row14_col10 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_532af_row0_col15, #T_532af_row1_col14, #T_532af_row2_col15, #T_532af_row14_col11 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_532af_row1_col0, #T_532af_row14_col13 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_532af_row1_col2, #T_532af_row6_col15, #T_532af_row10_col14 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_532af_row1_col3, #T_532af_row1_col7, #T_532af_row1_col12, #T_532af_row4_col0, #T_532af_row7_col15 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_532af_row1_col5, #T_532af_row1_col15, #T_532af_row2_col13, #T_532af_row5_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_532af_row1_col6, #T_532af_row1_col8, #T_532af_row2_col8, #T_532af_row3_col9, #T_532af_row9_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_532af_row1_col9, #T_532af_row6_col2, #T_532af_row7_col9 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_532af_row1_col10, #T_532af_row4_col13, #T_532af_row6_col9, #T_532af_row8_col1, #T_532af_row9_col11, #T_532af_row10_col9, #T_532af_row12_col2 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_532af_row1_col13, #T_532af_row3_col1, #T_532af_row3_col4, #T_532af_row8_col2, #T_532af_row11_col1, #T_532af_row12_col1, #T_532af_row14_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_532af_row2_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_532af_row2_col10, #T_532af_row9_col6, #T_532af_row13_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_532af_row2_col11, #T_532af_row5_col2, #T_532af_row11_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_532af_row2_col12, #T_532af_row4_col12, #T_532af_row9_col1, #T_532af_row10_col1, #T_532af_row13_col15, #T_532af_row15_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_532af_row2_col14, #T_532af_row4_col10, #T_532af_row13_col14 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_532af_row3_col2, #T_532af_row3_col6, #T_532af_row4_col6, #T_532af_row4_col7, #T_532af_row9_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_532af_row3_col7, #T_532af_row14_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_532af_row3_col10, #T_532af_row6_col3, #T_532af_row9_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_532af_row3_col11, #T_532af_row11_col14 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_532af_row3_col13, #T_532af_row4_col5, #T_532af_row4_col14, #T_532af_row14_col9 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_532af_row3_col14, #T_532af_row11_col4, #T_532af_row14_col3 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_532af_row4_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_532af_row4_col8, #T_532af_row5_col4 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_532af_row4_col9, #T_532af_row8_col13 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_532af_row4_col11, #T_532af_row10_col15, #T_532af_row15_col6 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_532af_row4_col15, #T_532af_row14_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_532af_row5_col3, #T_532af_row8_col10, #T_532af_row9_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_532af_row5_col6, #T_532af_row6_col5 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_532af_row5_col7 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_532af_row5_col8 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_532af_row5_col10, #T_532af_row10_col13 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_532af_row5_col11 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_532af_row5_col12, #T_532af_row11_col13 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_532af_row5_col13, #T_532af_row6_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_532af_row5_col14, #T_532af_row10_col6 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_532af_row5_col15, #T_532af_row8_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_532af_row6_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_532af_row6_col7 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_532af_row6_col10 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_532af_row6_col11, #T_532af_row14_col5 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_532af_row6_col12 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_532af_row6_col13 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_532af_row6_col14, #T_532af_row10_col3, #T_532af_row13_col8 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_532af_row7_col3, #T_532af_row8_col11 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_532af_row7_col5 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_532af_row7_col6 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_532af_row7_col8 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_532af_row7_col10, #T_532af_row7_col11, #T_532af_row12_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_532af_row7_col12, #T_532af_row8_col7 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_532af_row7_col13 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_532af_row7_col14 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_532af_row8_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_532af_row8_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_532af_row8_col5 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_532af_row8_col9 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_532af_row8_col14, #T_532af_row14_col8 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_532af_row8_col15, #T_532af_row15_col8 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_532af_row9_col3, #T_532af_row9_col13 {
#   backgrou

# %% [markdown]
# ### 2- Escolha 2 valores de K e mostre os resultados (escolha 2 métricas de avaliação e mostre a matriz de confusão)?

# %%
from sklearn import cluster, neighbors, svm, metrics, preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
# Fazendo a divisão dos dados para treinamento e testes
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1, stratify=y)

# %%
import pandas as pd
df = pd.read_csv('./international_matches.csv')
#df = pd.read_csv('./EPL_20_21.csv')
df

#print('Valores faltantes:\n', df.isnull().sum())

# %%
df.describe()

# %%
print('Valores duplicados:\n', df.duplicated())
